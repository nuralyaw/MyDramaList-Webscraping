# %% [markdown]
# # 1. Import libraries

# %%
import pandas as pd

from bs4 import BeautifulSoup

import requests
import re
import numpy as np

# %% [markdown]
# # 2. Getting the URLs for each K-Drama

# %%
default_URL = "https://mydramalist.com"
drama_URL = []

for i in range(1, 2):
    page_URL = f"https://mydramalist.com/search?adv=titles&ty=68&co=3&st=3&so=top&page={i}"

    try:
        result = requests.get(page_URL)
        result.raise_for_status()
        soup = BeautifulSoup(result.content, "html.parser") # Creating the soup object which we will be able to scrape

        drama_URL.extend((default_URL + x.get('href')) for x in soup.find_all('a', class_='block'))

    except requests.exceptions.RequestException as e:
        print(f"Error during request: {e}")

# %% [markdown]
# # 3. Initialising a dataframe

# %%
kdrama_df = pd.DataFrame(columns=['Title', 'URL', 'Genres', 'Tags', 'Description', 'Score', 'Users Scored', 'Episodes', 'Content Rating'])

# %%
kdrama_df['URL'] = drama_URL

# %% [markdown]
# # 4. Scraping relevant data

# %% [markdown]
# ## Title

# %%
def req(url):
    result = requests.get(url)
    return BeautifulSoup(result.text, 'html.parser')

# %%
kdrama_df['Title'] = kdrama_df['URL'].apply(lambda x: req(x).find('h1', class_= 'film-title').text)

# %% [markdown]
# # Genre

# %%
def get_genres(x):

    try:
        genres = req(x).find('li', class_='list-item p-a-0 show-genres')
        if genres:
            return genres.text.split(':', 1)[1].strip()
        else:
            return "Unknown"

    except Exception as e:
        print(f"An error occurred: {e}")
        return "Error"

# %%
kdrama_df['Genres'] = kdrama_df['URL'].apply(get_genres)

# %% [markdown]
# ## Tags

# %%
def get_tags(x):

    tags = req(x).find('li', attrs = {'class':'list-item p-a-0 show-tags'})
    if tags:
      tags = tags.text.split(':',1)[1].strip().replace('(Vote or add tags)','')
      return tags
    else:
      return "Unknown"

# %%
kdrama_df['Tags'] = kdrama_df['URL'].apply(get_tags)

# %% [markdown]
# ## Description

# %%
def get_synopsis(x):

    synopsis = req(x).find('div', class_="show-synopsis" )
    if synopsis:
      synopsis = synopsis.text.split('Edit Translation')[0].replace('\n', '').strip()
      return synopsis
    else:
      return "Unknown"

# %%
kdrama_df['Description'] = kdrama_df['URL'].apply(get_synopsis)

# %% [markdown]
# ## Remaining Attributes

# %%
def get_attributes(x):
  try:
    drama_details = []

    for row in req(x).findAll('li', attrs = {'class':'list-item p-a-0'}):
      drama_details.append(row.text)


    num_episodes = None
    score = None
    num_users_scored = None
    content_rating = None

    for detail in drama_details:

      if 'Episodes:' in detail:
        num_episodes = int(detail.split(':')[1].strip())

      elif 'Score:' in detail:
        score = detail.split(':')[1].split('(')[0].strip()
        num_users_scored = int(detail.split('(')[1].split('scored by')[1].split('users')[0].replace(',', '').strip())

      elif 'Content Rating:' in detail:
        content_rating = detail.split(':')[1].strip()

    return num_episodes, score, num_users_scored, content_rating

  except Exception as e:
    pass

# %%
attribute_results = kdrama_df['URL'].apply(get_attributes)

# %%
kdrama_df[['Episodes', 'Score', 'Users Scored', 'Content Rating']] = list(attribute_results)

# %%
kdrama_df
# Out:
#                                                 Title  \
# 0                                       Moving (2023)
# 1                               Move to Heaven (2021)
# 6   Transmigration, Master-Disciple Relationship, ...
# 7   Nostalgia, Multiple Couples, Poor Family, Love...
# 8   Nice Male Lead, Depression, Healing, Poor Fema...
# 9   Motherhood, Mother-Son Relationship, Palace Se...
# 10  Revenge, Graphic Violence, Brief Nudity, Suspe...
# 11  North And South Korea, Strong Male Lead, Rich ...
# 12  Prison Setting, Life Lesson, Bromance, Wrongfu...
# 13  Transmigration, Sassy Female Lead, Joseon Dyna...
# 14  Hospital Setting, Teamwork, Genius Male Lead, ...
# 15  Mother-Daughter Relationship, Independent Fema...
# 16  Possessive Female Lead, Independent Female Lea...
# 17  Autistic Female Lead, Autism, Attorney Female ...
# 18  Strong Male Lead, Marriage Of Convenience, Fan...
# 19  Ballet, Life Lesson, Unusual Friendship, Adapt...
#
#                                           Description Score Users Scored  \
# 0   Kim Bong Seok, Jang Hee Soo, and Lee Gang Hoon...   9.2        13835
# 1   Han Geu Roo is an autistic 20-year-old. He wor...   9.2        39327
# 2   Yeon Shi Eun is a model student who ranks at t...   9.1        28278
# 3   Everyday is extraordinary for five doctors and...   9.1        26007
# 4   Although Baek Hee Sung is hiding a dark secret...   9.1        52959
# 5   The stories of people going through their days...   9.1        42013
# 6   Set in a fictional country called Daeho that d...   9.1        43177
# 7   Five childhood friends, who all live in the sa...   9.1        42509
# 8   Park Dong Hoon is a middle-aged engineer who i...   9.0        25853
# 9   Within the palace exist troublemaking princes ...   9.0        11980
# 10  Moon Dong Eun's silent fury against those stud...   9.0        36056
# 11  After getting into a paragliding accident, Sou...   9.0        95824
# 12  Kim Je Hyuk, a famous baseball player, is arre...   9.0        27297
# 13  Jang Bong Hwan is a South Korean chef who has ...   9.0        41652
# 14  At Doldam Hospital, Dr. Kim Sa Bu and his team...   9.0         8496
# 15  Realizing one of her students is being abused,...   9.0         8881
# 16  Moon Gang Tae is a community health worker at ...   8.9        96557
# 17  Diagnosed with autism spectrum disorder, 27-ye...   8.9        56338
# 18  Jang Uk returns from death, and three years la...   8.9        31211
# 19  A 70-year-old with a dream and a 23-year-old w...   8.9        16380
#
#    Episodes                         Content Rating
# 0        20  18+ Restricted (violence & profanity)
# 1        10  18+ Restricted (violence & profanity)
# 2         8  18+ Restricted (violence & profanity)
# 3        12                15+ - Teens 15 or older
# 4        16                15+ - Teens 15 or older
# 5        12                15+ - Teens 15 or older
# 6        20                15+ - Teens 15 or older
# 7        20                15+ - Teens 15 or older
# 8        16                15+ - Teens 15 or older
# 9        16                15+ - Teens 15 or older
# 10        8  18+ Restricted (violence & profanity)
# 11       16                15+ - Teens 15 or older
# 12       16                15+ - Teens 15 or older
# 13       20                15+ - Teens 15 or older
# 14       16                15+ - Teens 15 or older
# 15       16                15+ - Teens 15 or older
# 16       16                15+ - Teens 15 or older
# 17       16                15+ - Teens 15 or older
# 18       10                15+ - Teens 15 or older
# 19       12                15+ - Teens 15 or older

# %% [markdown]
# # 5. Save dataframe as csv file

# %%
kdrama_df.to_csv('subset1.csv')
